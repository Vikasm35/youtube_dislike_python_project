# %% [markdown]
# ## 1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv('youtube_dislike_dataset.csv')
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
df.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ## 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# There are totally 37422 rows and 12 columns in the given dataset

# %% [markdown]
# only comments column has null values

# %% [markdown]
# in the given dataset 8 column consist of string(object) and 4 column consist of int

# %%
df.shape
# Out:
# (37422, 12)

# %% [markdown]
# ## 3. Check for the Percentage of the missing values and drop or impute them.

# %%
df.isnull().sum()/df.shape[0]*100  #comments column consist of 0.42% missing values
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
df.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum() # all the missing values are dropped
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# ## 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
df.describe(include='all')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37264  37264                     37264                37264
# unique        37264  36958                     10891                10813
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
# mean            NaN    NaN                       NaN                  NaN
# std             NaN    NaN                       NaN                  NaN
# min             NaN    NaN                       NaN                  NaN
# 25%             NaN    NaN                       NaN                  NaN
# 50%             NaN    NaN                       NaN                  NaN
# 75%             NaN    NaN                       NaN                  NaN
# max             NaN    NaN                       NaN                  NaN
#
#                published_at    view_count         likes      dislikes  \
# ...

# %% [markdown]
# average view_count for a video = 5.710821e+06
#
#
# maximum view_count for a video = 1.322797e+09
#
#
# maximum likes for a video = 3.183768e+07
#
#
# maximum dislikes for a video = 2.397733e+06

# %% [markdown]
# ## 5. Convert datatype of column published_at from object to pandas datetime.

# %%
pd.DataFrame(pd.to_datetime(df['published_at']))
# Out:
#              published_at
# 0     2021-07-01 10:00:00
# 1     2021-06-10 16:00:00
# 2     2021-09-20 01:03:32
# 3     2021-03-03 10:00:17
# 4     2021-12-07 13:00:00
# ...                   ...
# 37417 2021-02-12 05:03:49
# 37418 2021-01-16 05:39:05
# 37419 2021-06-02 09:00:10
# 37420 2020-10-20 20:59:30
# 37421 2021-05-23 21:00:31
#
# [37264 rows x 1 columns]

# %% [markdown]
# ## 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
df['published_month'] = df['published_at'].str[5:7]
df[['published_month']]
# Out:
#       published_month
# 0                  07
# 1                  06
# 2                  09
# 3                  03
# 4                  12
# ...               ...
# 37417              02
# 37418              01
# 37419              06
# 37420              10
# 37421              05
#
# [37264 rows x 1 columns]

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# ## 7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb' and so on.....

# %%
months = {'01':'Jan','02':'Feb','03':'Mar','04':'Apr','05':'May','06':'Jun','07':'Jul','08':'Aug','09':'Sep','10':'Oct','11':'Nov','12':'Dec'}
months
# Out:
# {'01': 'Jan',
#  '02': 'Feb',
#  '03': 'Mar',
#  '04': 'Apr',
#  '05': 'May',
#  '06': 'Jun',
#  '07': 'Jul',
#  '08': 'Aug',
#  '09': 'Sep',
#  '10': 'Oct',
#  '11': 'Nov',
#  '12': 'Dec'}

# %%
df['published_month'] = df['published_month'].map(months)
df['published_month']
# Out:
# 0        Jul
# 1        Jun
# 2        Sep
# 3        Mar
# 4        Dec
#         ...
# 37417    Feb
# 37418    Jan
# 37419    Jun
# 37420    Oct
# 37421    May
# Name: published_month, Length: 37264, dtype: object

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %% [markdown]
# ## 8. Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
pd.DataFrame(df.groupby('published_month')['video_id'].count().sort_values(ascending = False))
# Out:
#                  video_id
# published_month
# Oct                  4976
# Sep                  4854
# Nov                  4821
# Aug                  4250
# Dec                  3063
# Jul                  2331
# Jun                  2305
# Mar                  2248
# Feb                  2125
# Apr                  2119
# Jan                  2099
# May                  2073

# %% [markdown]
# ## 9. Find the count of unique video_id, channel_id and channel_title.

# %%
len(df['video_id'].unique()),len(df['channel_id'].unique()),len(df['channel_title'].unique())
# Out:
# (37264, 10891, 10813)

# %% [markdown]
# ## 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
pd.DataFrame(df.groupby('channel_title')['video_id'].count().sort_values(ascending = False).head(10))
# Out:
#                      video_id
# channel_title
# Sky Sports Football       533
# The United Stand          301
# BT Sport                  246
# NBA                       209
# NFL                       162
# WWE                       122
# SSSniperWolf               99
# SSundee                    98
# FORMULA 1                  87
# NHL                        86

# %%
pd.DataFrame(df.groupby('channel_title')['video_id'].count().sort_values(ascending = False).tail(10))
# Out:
#                  video_id
# channel_title
# Karikku Tuned           1
# Karen Bustillos         1
# Karen Aslanyan          1
# Karchez                 1
# Karate Combat           1
# Kaptain Kuba            1
# Kanye West              1
# Kannur kitchen          1
# Kannada Cinema          1
# zoom                    1

# %% [markdown]
# ## 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
pd.DataFrame(df.groupby('title')['likes'].max().sort_values(ascending = False).head())
# Out:
#                                                     likes
# title
# BTS () 'Dynamite' Official MV                    31837675
# BTS () 'Butter' Official MV                      20649409
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V  17864527
# BTS () 'Life Goes On' Official MV                16354127
# BTS () 'Permission to Dance' Official MV         15449003

# %% [markdown]
# BTS Dynamic official MV has highest number of likes = 31837675

# %%
pd.DataFrame(df.groupby('title')['likes'].max().sort_values(ascending = False).tail())
# Out:
#                                                 likes
# title
# Virtual Pub Quiz, Live! Thursday 8th July         106
# Virtual Pub Quiz, Live! Saturday 12th December     97
# Small Business Loans from OnDeck                   29
# Tims For Good: A Taste Of The Familiar             28
# Leading the Charge | Circle K                      22

# %% [markdown]
# #### Leading the Charge | Circle K has lowest number of likes = 22

# %% [markdown]
# ## 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
pd.DataFrame(df.groupby('title')['dislikes'].max().sort_values(ascending = False).tail())
# Out:
#                                                     dislikes
# title
# Leicester v Gloucester | Wigglesworth Impresses...         7
# YONEX Thailand Open | Day 3: Saina Nehwal (IND)...         7
# Leeds Rhinos vs Wakefield Trinity | Super Leagu...         6
# Live Stream: Hampshire v Yorkshire - LV= County...         4
# Tims For Good: A Taste Of The Familiar                     3

# %% [markdown]
# Tims For Good: A Taste Of The Familiar has minimum number of dislike is 3

# %%
pd.DataFrame(df.groupby('title')['dislikes'].max().sort_values(ascending = False).head())
# Out:
#                                                     dislikes
# title
# Cuties | Official Trailer | Netflix                  2397733
# BTS () 'Dynamite' Official MV                        1814333
# Cardi B - WAP feat. Megan Thee Stallion [Offici...   1331181
# 52 GAJ KA DAMAN | PRANJAL DAHIYA | AMAN JAJI | ...   1259533
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V      1253187

# %% [markdown]
# Cuties | Official Trailer | Netflix maximum number of dislikes = 2397733

# %% [markdown]
# ## 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
df['dislikes rate']=df['dislikes']/df['view_count']*100

# %%
df.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
pd.DataFrame(df[['dislikes rate','view_count']]).plot(x='view_count',y='dislikes rate',kind='scatter')
# Out:
# <AxesSubplot:xlabel='view_count', ylabel='dislikes rate'>

# %%
sns.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [raw]
# Scatter plot also follows a certain trend and pattern from left to right which shows there is a correlation using dislike rate
#
#
# The correlation between views and dislikes is [0.68] which can be considered as moderate to higher correlation. So from this we can conclude that views have a signnificance in determining the dislikes of a video

# %% [markdown]
# ## 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
df[df['published_month']=='Jan']
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title         published_at  \
# ...

# %%
df[df['published_month']=='Jan']['video_id'].count()
# Out:
# 2099

# %% [markdown]
# 2099 videos were published in january
